# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import gzip
import os
import tempfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf
from tensorflow.contrib.learn.python.learn.datasets.mnist import read_data_sets

# %%
mnist = read_data_sets("/home/wxk/Ipython/MINIST_RNN/data/", one_hot=True)
# Out:
# Extracting /home/wxk/Ipython/MINIST_RNN/data/train-images-idx3-ubyte.gz
# Extracting /home/wxk/Ipython/MINIST_RNN/data/train-labels-idx1-ubyte.gz
# Extracting /home/wxk/Ipython/MINIST_RNN/data/t10k-images-idx3-ubyte.gz
# Extracting /home/wxk/Ipython/MINIST_RNN/data/t10k-labels-idx1-ubyte.gz

# %%
learning_rate = 0.001
training_iters = 100000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 28 # MNIST data input (img shape: 28*28)
n_steps = 28 # timesteps
n_hidden = 128 # hidden layer num of features
n_classes = 10 # MNIST total classes (0-9 digits)

# %%
# tf Graph input
x = tf.placeholder("float", [None, n_steps, n_input])
istate = tf.placeholder("float", [None, 2*n_hidden]) #state & cell => 2x n_hidden
y = tf.placeholder("float", [None, n_classes])

# Define weights
weights = {
    'hidden': tf.Variable(tf.random_normal([n_input, n_hidden])), # Hidden layer weights
    'out': tf.Variable(tf.random_normal([n_hidden, n_classes]))
}
biases = {
    'hidden': tf.Variable(tf.random_normal([n_hidden])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %%
def RNN(_X, _istate, _weights, _biases):

    # input shape: (batch_size, n_steps, n_input)
    _X = tf.transpose(_X, [1, 0, 2])  # permute n_steps and batch_size
    # Reshape to prepare input to hidden activation
    _X = tf.reshape(_X, [-1, n_input]) # (n_steps*batch_size, n_input)
    # Linear activation
    _X = tf.matmul(_X, _weights['hidden']) + _biases['hidden']

    # Define a lstm cell with tensorflow
    lstm_cell = tf.nn.rnn_cell.BasicLSTMCell(n_hidden, forget_bias=1.0)
    # Split data because rnn cell needs a list of inputs for the RNN inner loop
    _X = tf.split(0, n_steps, _X) # n_steps * (batch_size, n_hidden)

    # Get lstm cell output
   # outputs, states = tf.rnn.rnn(lstm_cell, _X, initial_state=_istate)
    outputs, states = tf.nn.rnn(lstm_cell, _X, initial_state=_istate)

    # Linear activation
    # Get inner loop last output
    return tf.matmul(outputs[-1], _weights['out']) + _biases['out']

# %%
pred = RNN(x, istate, weights, biases)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y)) # Softmax loss
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost) # Adam Optimizer

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell.BasicLSTMCell object at 0x7f87fb923750>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.

# %%
training_iters=500

# %%
init = tf.initialize_all_variables()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_xs, batch_ys = mnist.train.next_batch(batch_size)
        # Reshape data to get 28 seq of 28 elements
        batch_xs = batch_xs.reshape((batch_size, n_steps, n_input))
        # Fit training using batch data
        sess.run(optimizer, feed_dict={x: batch_xs, y: batch_ys,
                                       istate: np.zeros((batch_size, 2*n_hidden))})
        if step % 1 == 0:
            # Calculate batch accuracy
            acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys,
                                                istate: np.zeros((batch_size, 2*n_hidden))})
            # Calculate batch loss
            loss = sess.run(cost, feed_dict={x: batch_xs, y: batch_ys,
                                             istate: np.zeros((batch_size, 2*n_hidden))})
            print ("Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss)
                  , "Training Accuracy= " + "{:.5f}".format(acc))
        step += 1
    print ("Optimization Finished!")
    # Calculate accuracy for 256 mnist test images
    test_len = 256
    test_data = mnist.test.images[:test_len].reshape((-1, n_steps, n_input))
    test_label = mnist.test.labels[:test_len]
    print ("Testing Accuracy:", sess.run(accuracy, feed_dict={x: test_data, y: test_label,
                                                             istate: np.zeros((test_len, 2*n_hidden))}))
# Out:
# Iter 128, Minibatch Loss= 4.690147 Training Accuracy= 0.07812
# Iter 256, Minibatch Loss= 3.518187 Training Accuracy= 0.14062
# Iter 384, Minibatch Loss= 3.463385 Training Accuracy= 0.24219
# Iter 512, Minibatch Loss= 3.346823 Training Accuracy= 0.12500
# Iter 640, Minibatch Loss= 2.757995 Training Accuracy= 0.26562
# Iter 768, Minibatch Loss= 2.632147 Training Accuracy= 0.23438
# Iter 896, Minibatch Loss= 1.976800 Training Accuracy= 0.36719
# Iter 1024, Minibatch Loss= 1.959689 Training Accuracy= 0.34375
# Iter 1152, Minibatch Loss= 1.848680 Training Accuracy= 0.38281
# Iter 1280, Minibatch Loss= 1.785549 Training Accuracy= 0.32031
# Iter 1408, Minibatch Loss= 1.775844 Training Accuracy= 0.33594
# Iter 1536, Minibatch Loss= 1.827579 Training Accuracy= 0.27344
# Iter 1664, Minibatch Loss= 1.679258 Training Accuracy= 0.42188
# Iter 1792, Minibatch Loss= 1.736885 Training Accuracy= 0.40625
# Iter 1920, Minibatch Loss= 1.722502 Training Accuracy= 0.39844
# Iter 2048, Minibatch Loss= 1.558571 Training Accuracy= 0.46875
# Iter 2176, Minibatch Loss= 1.676429 Training Accuracy= 0.49219
# Iter 2304, Minibatch Loss= 1.628253 Training Accuracy= 0.49219
# Iter 2432, Minibatch Loss= 1.638801 Training Accuracy= 0.42188
# Iter 2560, Minibatch Loss= 1.572941 Training Accuracy= 0.48438
# Iter 2688, Minibatch Loss= 1.515914 Training Accuracy= 0.53906
# Iter 2816, Minibatch Loss= 1.630440 Training Accuracy= 0.42188
# Iter 2944, Minibatch Loss= 1.296458 Training Accuracy= 0.50781
# Iter 3072, Minibatch Loss= 1.351060 Training Accuracy= 0.52344
# Iter 3200, Minibatch Loss= 1.224114 Training Accuracy= 0.57812
# Iter 3328, Minibatch Loss= 1.495600 Training Accuracy= 0.52344
# Iter 3456, Minibatch Loss= 1.334728 Training Accuracy= 0.54688
# Iter 3584, Minibatch Loss= 1.189464 Training Accuracy= 0.59375
# Iter 3712, Minibatch Loss= 1.463234 Training Accuracy= 0.55469
# Iter 3840, Minibatch Loss= 1.340032 Training Accuracy= 0.58594
# Iter 3968, Minibatch Loss= 1.361171 Training Accuracy= 0.57812
# Iter 4096, Minibatch Loss= 0.962029 Training Accuracy= 0.67188
# Iter 4224, Minibatch Loss= 1.087958 Training Accuracy= 0.61719
# Iter 4352, Minibatch Loss= 0.905089 Training Accuracy= 0.73438
# Iter 4480, Minibatch Loss= 1.270700 Training Accuracy= 0.59375
# Iter 4608, Minibatch Loss= 1.135898 Training Accuracy= 0.53125
# Iter 4736, Minibatch Loss= 0.876324 Training Accuracy= 0.67188
# Iter 4864, Minibatch Loss= 1.132793 Training Accuracy= 0.62500
# Iter 4992, Minibatch Loss= 0.880232 Training Accuracy= 0.72656
# Iter 5120, Minibatch Loss= 0.946038 Training Accuracy= 0.67969
# Iter 5248, Minibatch Loss= 1.011494 Training Accuracy= 0.71094
# Iter 5376, Minibatch Loss= 1.062421 Training Accuracy= 0.64062
# Iter 5504, Minibatch Loss= 1.093411 Training Accuracy= 0.68750
# Iter 5632, Minibatch Loss= 0.852172 Training Accuracy= 0.73438
# Iter 5760, Minibatch Loss= 0.995806 Training Accuracy= 0.71094
# Iter 5888, Minibatch Loss= 0.846796 Training Accuracy= 0.68750
# Iter 6016, Minibatch Loss= 0.919660 Training Accuracy= 0.67188
# Iter 6144, Minibatch Loss= 0.858647 Training Accuracy= 0.70312
# Iter 6272, Minibatch Loss= 0.882374 Training Accuracy= 0.67188
# Iter 6400, Minibatch Loss= 0.847904 Training Accuracy= 0.71875
# Iter 6528, Minibatch Loss= 0.687252 Training Accuracy= 0.79688
# Iter 6656, Minibatch Loss= 0.799696 Training Accuracy= 0.73438
# Iter 6784, Minibatch Loss= 0.780624 Training Accuracy= 0.72656
# Iter 6912, Minibatch Loss= 0.851733 Training Accuracy= 0.71094
# Iter 7040, Minibatch Loss= 0.766650 Training Accuracy= 0.71875
# Iter 7168, Minibatch Loss= 0.559301 Training Accuracy= 0.80469
# Iter 7296, Minibatch Loss= 1.003267 Training Accuracy= 0.71875
# Iter 7424, Minibatch Loss= 0.870711 Training Accuracy= 0.73438
# Iter 7552, Minibatch Loss= 0.895803 Training Accuracy= 0.68750
# Iter 7680, Minibatch Loss= 1.032757 Training Accuracy= 0.68750
# Iter 7808, Minibatch Loss= 0.945984 Training Accuracy= 0.69531
# Iter 7936, Minibatch Loss= 0.837630 Training Accuracy= 0.70312
# Iter 8064, Minibatch Loss= 0.968605 Training Accuracy= 0.70312
# Iter 8192, Minibatch Loss= 1.129454 Training Accuracy= 0.66406
# Iter 8320, Minibatch Loss= 0.591089 Training Accuracy= 0.80469
# Iter 8448, Minibatch Loss= 0.767817 Training Accuracy= 0.73438
# Iter 8576, Minibatch Loss= 0.742789 Training Accuracy= 0.74219
# Iter 8704, Minibatch Loss= 0.668786 Training Accuracy= 0.78125
# Iter 8832, Minibatch Loss= 0.712425 Training Accuracy= 0.74219
# Iter 8960, Minibatch Loss= 0.813584 Training Accuracy= 0.71094
# Iter 9088, Minibatch Loss= 0.879265 Training Accuracy= 0.66406
# Iter 9216, Minibatch Loss= 0.697813 Training Accuracy= 0.76562
# Iter 9344, Minibatch Loss= 0.905401 Training Accuracy= 0.64062
# Iter 9472, Minibatch Loss= 0.808323 Training Accuracy= 0.71875
# Iter 9600, Minibatch Loss= 0.771276 Training Accuracy= 0.73438
# Iter 9728, Minibatch Loss= 1.047050 Training Accuracy= 0.66406
# Iter 9856, Minibatch Loss= 0.945616 Training Accuracy= 0.69531
# Iter 9984, Minibatch Loss= 0.698451 Training Accuracy= 0.80469
# Iter 10112, Minibatch Loss= 0.762372 Training Accuracy= 0.80469
# Iter 10240, Minibatch Loss= 0.763972 Training Accuracy= 0.74219
# Iter 10368, Minibatch Loss= 0.698142 Training Accuracy= 0.76562
# Iter 10496, Minibatch Loss= 0.741102 Training Accuracy= 0.75000
# Iter 10624, Minibatch Loss= 0.754560 Training Accuracy= 0.76562
# Iter 10752, Minibatch Loss= 0.736474 Training Accuracy= 0.75000
# Iter 10880, Minibatch Loss= 0.909120 Training Accuracy= 0.71094
# Iter 11008, Minibatch Loss= 0.762648 Training Accuracy= 0.73438
# Iter 11136, Minibatch Loss= 0.811499 Training Accuracy= 0.75000
# Iter 11264, Minibatch Loss= 0.652530 Training Accuracy= 0.80469
# Iter 11392, Minibatch Loss= 0.566764 Training Accuracy= 0.82031
# Iter 11520, Minibatch Loss= 0.513549 Training Accuracy= 0.83594
# Iter 11648, Minibatch Loss= 0.581322 Training Accuracy= 0.78125
# Iter 11776, Minibatch Loss= 0.720890 Training Accuracy= 0.76562
# Iter 11904, Minibatch Loss= 0.670887 Training Accuracy= 0.75781
# Iter 12032, Minibatch Loss= 0.717658 Training Accuracy= 0.77344
# Iter 12160, Minibatch Loss= 0.619187 Training Accuracy= 0.81250
# Iter 12288, Minibatch Loss= 0.587029 Training Accuracy= 0.78906
# Iter 12416, Minibatch Loss= 0.656657 Training Accuracy= 0.80469
# Iter 12544, Minibatch Loss= 0.696821 Training Accuracy= 0.77344
# Iter 12672, Minibatch Loss= 0.737660 Training Accuracy= 0.76562
# Iter 12800, Minibatch Loss= 0.825969 Training Accuracy= 0.70312
# Iter 12928, Minibatch Loss= 0.586298 Training Accuracy= 0.78906
# Iter 13056, Minibatch Loss= 0.435777 Training Accuracy= 0.84375
# Iter 13184, Minibatch Loss= 0.495968 Training Accuracy= 0.85156
# Iter 13312, Minibatch Loss= 0.497629 Training Accuracy= 0.84375
# Iter 13440, Minibatch Loss= 0.749103 Training Accuracy= 0.74219
# Iter 13568, Minibatch Loss= 0.577758 Training Accuracy= 0.78906
# Iter 13696, Minibatch Loss= 0.617523 Training Accuracy= 0.82031
# Iter 13824, Minibatch Loss= 0.553724 Training Accuracy= 0.83594
# Iter 13952, Minibatch Loss= 0.480802 Training Accuracy= 0.80469
# Iter 14080, Minibatch Loss= 0.518121 Training Accuracy= 0.82031
# Iter 14208, Minibatch Loss= 0.623342 Training Accuracy= 0.82031
# Iter 14336, Minibatch Loss= 0.494958 Training Accuracy= 0.86719
# Iter 14464, Minibatch Loss= 0.569121 Training Accuracy= 0.79688
# Iter 14592, Minibatch Loss= 0.576741 Training Accuracy= 0.84375
# Iter 14720, Minibatch Loss= 0.546745 Training Accuracy= 0.82031
# Iter 14848, Minibatch Loss= 0.547399 Training Accuracy= 0.85938
# Iter 14976, Minibatch Loss= 0.531534 Training Accuracy= 0.83594
# Iter 15104, Minibatch Loss= 0.596740 Training Accuracy= 0.78125
# Iter 15232, Minibatch Loss= 0.728270 Training Accuracy= 0.78125
# Iter 15360, Minibatch Loss= 0.573687 Training Accuracy= 0.80469
# Iter 15488, Minibatch Loss= 0.492192 Training Accuracy= 0.87500
# Iter 15616, Minibatch Loss= 0.709033 Training Accuracy= 0.76562
# Iter 15744, Minibatch Loss= 0.606465 Training Accuracy= 0.78906
# Iter 15872, Minibatch Loss= 0.567420 Training Accuracy= 0.84375
# Iter 16000, Minibatch Loss= 0.621099 Training Accuracy= 0.80469
# Iter 16128, Minibatch Loss= 0.644962 Training Accuracy= 0.79688
# Iter 16256, Minibatch Loss= 0.591181 Training Accuracy= 0.80469
# Iter 16384, Minibatch Loss= 0.659754 Training Accuracy= 0.75000
# Iter 16512, Minibatch Loss= 0.594407 Training Accuracy= 0.78125
# Iter 16640, Minibatch Loss= 0.449075 Training Accuracy= 0.90625
# Iter 16768, Minibatch Loss= 0.389342 Training Accuracy= 0.88281
# Iter 16896, Minibatch Loss= 0.427346 Training Accuracy= 0.85938
# Iter 17024, Minibatch Loss= 0.393085 Training Accuracy= 0.86719
# Iter 17152, Minibatch Loss= 0.548025 Training Accuracy= 0.80469
# Iter 17280, Minibatch Loss= 0.499458 Training Accuracy= 0.84375
# Iter 17408, Minibatch Loss= 0.432781 Training Accuracy= 0.83594
# Iter 17536, Minibatch Loss= 0.692445 Training Accuracy= 0.76562
# Iter 17664, Minibatch Loss= 0.674877 Training Accuracy= 0.78906
# Iter 17792, Minibatch Loss= 0.443191 Training Accuracy= 0.87500
# Iter 17920, Minibatch Loss= 0.576773 Training Accuracy= 0.78906
# Iter 18048, Minibatch Loss= 0.349016 Training Accuracy= 0.90625
# Iter 18176, Minibatch Loss= 0.520797 Training Accuracy= 0.82812
# Iter 18304, Minibatch Loss= 0.351673 Training Accuracy= 0.89844
# Iter 18432, Minibatch Loss= 0.391043 Training Accuracy= 0.88281
# Iter 18560, Minibatch Loss= 0.389583 Training Accuracy= 0.85938
# Iter 18688, Minibatch Loss= 0.533191 Training Accuracy= 0.82031
# Iter 18816, Minibatch Loss= 0.478205 Training Accuracy= 0.83594
# Iter 18944, Minibatch Loss= 0.436491 Training Accuracy= 0.85938
# Iter 19072, Minibatch Loss= 0.552974 Training Accuracy= 0.85156
# Iter 19200, Minibatch Loss= 0.354832 Training Accuracy= 0.90625
# Iter 19328, Minibatch Loss= 0.554520 Training Accuracy= 0.82031
# Iter 19456, Minibatch Loss= 0.391376 Training Accuracy= 0.87500
# Iter 19584, Minibatch Loss= 0.484475 Training Accuracy= 0.83594
# Iter 19712, Minibatch Loss= 0.586402 Training Accuracy= 0.82031
# Iter 19840, Minibatch Loss= 0.428079 Training Accuracy= 0.85938
# Iter 19968, Minibatch Loss= 0.336090 Training Accuracy= 0.89844
# Iter 20096, Minibatch Loss= 0.339021 Training Accuracy= 0.89062
# Iter 20224, Minibatch Loss= 0.498368 Training Accuracy= 0.83594
# Iter 20352, Minibatch Loss= 0.397883 Training Accuracy= 0.82812
# Iter 20480, Minibatch Loss= 0.259833 Training Accuracy= 0.92969
# Iter 20608, Minibatch Loss= 0.466532 Training Accuracy= 0.87500
# Iter 20736, Minibatch Loss= 0.481183 Training Accuracy= 0.85156
# Iter 20864, Minibatch Loss= 0.573002 Training Accuracy= 0.84375
# Iter 20992, Minibatch Loss= 0.556896 Training Accuracy= 0.78125
# Iter 21120, Minibatch Loss= 0.322670 Training Accuracy= 0.89844
# Iter 21248, Minibatch Loss= 0.347041 Training Accuracy= 0.88281
# Iter 21376, Minibatch Loss= 0.388894 Training Accuracy= 0.89844
# Iter 21504, Minibatch Loss= 0.574820 Training Accuracy= 0.82812
# Iter 21632, Minibatch Loss= 0.592642 Training Accuracy= 0.82031
# Iter 21760, Minibatch Loss= 0.581129 Training Accuracy= 0.84375
# Iter 21888, Minibatch Loss= 0.437198 Training Accuracy= 0.83594
# Iter 22016, Minibatch Loss= 0.380526 Training Accuracy= 0.85156
# Iter 22144, Minibatch Loss= 0.423263 Training Accuracy= 0.82031
# Iter 22272, Minibatch Loss= 0.615456 Training Accuracy= 0.80469
# Iter 22400, Minibatch Loss= 0.535437 Training Accuracy= 0.84375
# Iter 22528, Minibatch Loss= 0.527958 Training Accuracy= 0.82812
# Iter 22656, Minibatch Loss= 0.286051 Training Accuracy= 0.89844
# Iter 22784, Minibatch Loss= 0.372107 Training Accuracy= 0.88281
# Iter 22912, Minibatch Loss= 0.434094 Training Accuracy= 0.89062
# Iter 23040, Minibatch Loss= 0.351604 Training Accuracy= 0.86719
# Iter 23168, Minibatch Loss= 0.326858 Training Accuracy= 0.91406
# Iter 23296, Minibatch Loss= 0.375334 Training Accuracy= 0.88281
# Iter 23424, Minibatch Loss= 0.500316 Training Accuracy= 0.85156
# Iter 23552, Minibatch Loss= 0.254323 Training Accuracy= 0.92969
# Iter 23680, Minibatch Loss= 0.436677 Training Accuracy= 0.88281
# Iter 23808, Minibatch Loss= 0.356595 Training Accuracy= 0.85938
# Iter 23936, Minibatch Loss= 0.414260 Training Accuracy= 0.89062
# Iter 24064, Minibatch Loss= 0.417675 Training Accuracy= 0.86719
# Iter 24192, Minibatch Loss= 0.339256 Training Accuracy= 0.88281
# Iter 24320, Minibatch Loss= 0.493443 Training Accuracy= 0.80469
# Iter 24448, Minibatch Loss= 0.496608 Training Accuracy= 0.86719
# Iter 24576, Minibatch Loss= 0.379197 Training Accuracy= 0.89844
# Iter 24704, Minibatch Loss= 0.394586 Training Accuracy= 0.88281
# Iter 24832, Minibatch Loss= 0.548799 Training Accuracy= 0.82031
# Iter 24960, Minibatch Loss= 0.532825 Training Accuracy= 0.80469
# Iter 25088, Minibatch Loss= 0.384279 Training Accuracy= 0.89062
# Iter 25216, Minibatch Loss= 0.454586 Training Accuracy= 0.89844
# Iter 25344, Minibatch Loss= 0.358264 Training Accuracy= 0.88281
# Iter 25472, Minibatch Loss= 0.409652 Training Accuracy= 0.87500
# Iter 25600, Minibatch Loss= 0.465953 Training Accuracy= 0.88281
# Iter 25728, Minibatch Loss= 0.369743 Training Accuracy= 0.89844
# Iter 25856, Minibatch Loss= 0.519779 Training Accuracy= 0.80469
# Iter 25984, Minibatch Loss= 0.612807 Training Accuracy= 0.78125
# Iter 26112, Minibatch Loss= 0.368308 Training Accuracy= 0.85938
# Iter 26240, Minibatch Loss= 0.501573 Training Accuracy= 0.85156
# Iter 26368, Minibatch Loss= 0.630995 Training Accuracy= 0.78906
# Iter 26496, Minibatch Loss= 0.394453 Training Accuracy= 0.87500
# Iter 26624, Minibatch Loss= 0.416138 Training Accuracy= 0.86719
# Iter 26752, Minibatch Loss= 0.583312 Training Accuracy= 0.81250
# Iter 26880, Minibatch Loss= 0.306617 Training Accuracy= 0.89844
# Iter 27008, Minibatch Loss= 0.326686 Training Accuracy= 0.89062
# Iter 27136, Minibatch Loss= 0.573359 Training Accuracy= 0.79688
# Iter 27264, Minibatch Loss= 0.303995 Training Accuracy= 0.91406
# Iter 27392, Minibatch Loss= 0.485920 Training Accuracy= 0.85938
# Iter 27520, Minibatch Loss= 0.514435 Training Accuracy= 0.80469
# Iter 27648, Minibatch Loss= 0.259528 Training Accuracy= 0.92969
# Iter 27776, Minibatch Loss= 0.505368 Training Accuracy= 0.84375
# Iter 27904, Minibatch Loss= 0.357605 Training Accuracy= 0.90625
# Iter 28032, Minibatch Loss= 0.265467 Training Accuracy= 0.92188
# Iter 28160, Minibatch Loss= 0.294810 Training Accuracy= 0.91406
# Iter 28288, Minibatch Loss= 0.318224 Training Accuracy= 0.88281
# Iter 28416, Minibatch Loss= 0.460507 Training Accuracy= 0.83594
# Iter 28544, Minibatch Loss= 0.311542 Training Accuracy= 0.88281
# Iter 28672, Minibatch Loss= 0.282956 Training Accuracy= 0.90625
# Iter 28800, Minibatch Loss= 0.401830 Training Accuracy= 0.89062
# Iter 28928, Minibatch Loss= 0.199633 Training Accuracy= 0.93750
# Iter 29056, Minibatch Loss= 0.414153 Training Accuracy= 0.85156
# Iter 29184, Minibatch Loss= 0.265271 Training Accuracy= 0.91406
# Iter 29312, Minibatch Loss= 0.273043 Training Accuracy= 0.92969
# Iter 29440, Minibatch Loss= 0.420459 Training Accuracy= 0.86719
# Iter 29568, Minibatch Loss= 0.404693 Training Accuracy= 0.88281
# Iter 29696, Minibatch Loss= 0.391599 Training Accuracy= 0.84375
# Iter 29824, Minibatch Loss= 0.406714 Training Accuracy= 0.86719
# Iter 29952, Minibatch Loss= 0.409389 Training Accuracy= 0.85938
# Iter 30080, Minibatch Loss= 0.292217 Training Accuracy= 0.92188
# Iter 30208, Minibatch Loss= 0.309853 Training Accuracy= 0.89062
# Iter 30336, Minibatch Loss= 0.382906 Training Accuracy= 0.87500
# Iter 30464, Minibatch Loss= 0.285887 Training Accuracy= 0.89844
# Iter 30592, Minibatch Loss= 0.379189 Training Accuracy= 0.88281
# Iter 30720, Minibatch Loss= 0.299334 Training Accuracy= 0.90625
# Iter 30848, Minibatch Loss= 0.201092 Training Accuracy= 0.91406
# Iter 30976, Minibatch Loss= 0.407323 Training Accuracy= 0.85938
# Iter 31104, Minibatch Loss= 0.239001 Training Accuracy= 0.89844
# Iter 31232, Minibatch Loss= 0.352021 Training Accuracy= 0.87500
# Iter 31360, Minibatch Loss= 0.276971 Training Accuracy= 0.91406
# Iter 31488, Minibatch Loss= 0.336885 Training Accuracy= 0.90625
# Iter 31616, Minibatch Loss= 0.365430 Training Accuracy= 0.86719
# Iter 31744, Minibatch Loss= 0.221457 Training Accuracy= 0.94531
# Iter 31872, Minibatch Loss= 0.344481 Training Accuracy= 0.91406
# Iter 32000, Minibatch Loss= 0.317499 Training Accuracy= 0.86719
# Iter 32128, Minibatch Loss= 0.448024 Training Accuracy= 0.85156
# Iter 32256, Minibatch Loss= 0.279289 Training Accuracy= 0.89844
# Iter 32384, Minibatch Loss= 0.271387 Training Accuracy= 0.91406
# Iter 32512, Minibatch Loss= 0.351246 Training Accuracy= 0.89062
# Iter 32640, Minibatch Loss= 0.304217 Training Accuracy= 0.89844
# Iter 32768, Minibatch Loss= 0.383735 Training Accuracy= 0.90625
# Iter 32896, Minibatch Loss= 0.448171 Training Accuracy= 0.82812
# Iter 33024, Minibatch Loss= 0.374287 Training Accuracy= 0.88281
# Iter 33152, Minibatch Loss= 0.299140 Training Accuracy= 0.88281
# Iter 33280, Minibatch Loss= 0.263813 Training Accuracy= 0.92969
# Iter 33408, Minibatch Loss= 0.315155 Training Accuracy= 0.86719
# Iter 33536, Minibatch Loss= 0.246867 Training Accuracy= 0.94531
# Iter 33664, Minibatch Loss= 0.224530 Training Accuracy= 0.92188
# Iter 33792, Minibatch Loss= 0.224188 Training Accuracy= 0.93750
# Iter 33920, Minibatch Loss= 0.241147 Training Accuracy= 0.92969
# Iter 34048, Minibatch Loss= 0.310799 Training Accuracy= 0.90625
# Iter 34176, Minibatch Loss= 0.181419 Training Accuracy= 0.92188
# Iter 34304, Minibatch Loss= 0.266435 Training Accuracy= 0.89844
# Iter 34432, Minibatch Loss= 0.454304 Training Accuracy= 0.87500
# Iter 34560, Minibatch Loss= 0.430037 Training Accuracy= 0.88281
# Iter 34688, Minibatch Loss= 0.455420 Training Accuracy= 0.83594
# Iter 34816, Minibatch Loss= 0.365123 Training Accuracy= 0.87500
# Iter 34944, Minibatch Loss= 0.433190 Training Accuracy= 0.87500
# Iter 35072, Minibatch Loss= 0.228312 Training Accuracy= 0.94531
# Iter 35200, Minibatch Loss= 0.294486 Training Accuracy= 0.90625
# Iter 35328, Minibatch Loss= 0.234861 Training Accuracy= 0.92188
# Iter 35456, Minibatch Loss= 0.177374 Training Accuracy= 0.94531
# Iter 35584, Minibatch Loss= 0.290605 Training Accuracy= 0.91406
# Iter 35712, Minibatch Loss= 0.360252 Training Accuracy= 0.89844
# Iter 35840, Minibatch Loss= 0.227643 Training Accuracy= 0.93750
# Iter 35968, Minibatch Loss= 0.238351 Training Accuracy= 0.92969
# Iter 36096, Minibatch Loss= 0.360111 Training Accuracy= 0.89062
# Iter 36224, Minibatch Loss= 0.229415 Training Accuracy= 0.92969
# Iter 36352, Minibatch Loss= 0.377821 Training Accuracy= 0.91406
# Iter 36480, Minibatch Loss= 0.441042 Training Accuracy= 0.89062
# Iter 36608, Minibatch Loss= 0.349809 Training Accuracy= 0.89844
# Iter 36736, Minibatch Loss= 0.305434 Training Accuracy= 0.91406
# Iter 36864, Minibatch Loss= 0.269409 Training Accuracy= 0.89844
# Iter 36992, Minibatch Loss= 0.227789 Training Accuracy= 0.92969
# Iter 37120, Minibatch Loss= 0.315870 Training Accuracy= 0.92188
# Iter 37248, Minibatch Loss= 0.297559 Training Accuracy= 0.90625
# Iter 37376, Minibatch Loss= 0.484741 Training Accuracy= 0.82031
# Iter 37504, Minibatch Loss= 0.433490 Training Accuracy= 0.85938
# Iter 37632, Minibatch Loss= 0.406836 Training Accuracy= 0.86719
# Iter 37760, Minibatch Loss= 0.286096 Training Accuracy= 0.90625
# Iter 37888, Minibatch Loss= 0.263469 Training Accuracy= 0.89844
# Iter 38016, Minibatch Loss= 0.523914 Training Accuracy= 0.83594
# Iter 38144, Minibatch Loss= 0.299034 Training Accuracy= 0.92188
# Iter 38272, Minibatch Loss= 0.249213 Training Accuracy= 0.91406
# Iter 38400, Minibatch Loss= 0.142548 Training Accuracy= 0.96094
# Iter 38528, Minibatch Loss= 0.271759 Training Accuracy= 0.92969
# Iter 38656, Minibatch Loss= 0.287489 Training Accuracy= 0.91406
# Iter 38784, Minibatch Loss= 0.322121 Training Accuracy= 0.91406
# Iter 38912, Minibatch Loss= 0.315566 Training Accuracy= 0.88281

# %%
a =2

# %%
print("It took", time.time() - t, "seconds to train for 30 epochs.")

# %%
 print ("Optimization Finished!", a)
# Out:
# Optimization Finished! 2

# %%
print (a)
# Out:
# 2
