# %%
from __future__ import print_function, division
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

num_epochs = 100
total_series_length = 50000
truncated_backprop_length = 15
state_size = 4
num_classes = 2
echo_step = 3
batch_size = 5
num_batches = total_series_length//batch_size//truncated_backprop_length

def generateData():
    x = np.array(np.random.choice(2, total_series_length, p=[0.5, 0.5]))
    y = np.roll(x, echo_step)
    y[0:echo_step] = 0

    x = x.reshape((batch_size, -1))  # The first index changing slowest, subseries as rows
    y = y.reshape((batch_size, -1))

    return (x, y)

batchX_placeholder = tf.placeholder(tf.float32, [batch_size, truncated_backprop_length])
batchY_placeholder = tf.placeholder(tf.int32, [batch_size, truncated_backprop_length])

cell_state = tf.placeholder(tf.float32, [batch_size, state_size])
hidden_state = tf.placeholder(tf.float32, [batch_size, state_size])
init_state = tf.nn.rnn_cell.LSTMStateTuple(cell_state, hidden_state)

W2 = tf.Variable(np.random.rand(state_size, num_classes),dtype=tf.float32)
b2 = tf.Variable(np.zeros((1,num_classes)), dtype=tf.float32)

# Unpack columns
inputs_series = tf.split(1, truncated_backprop_length, batchX_placeholder)
labels_series = tf.unpack(batchY_placeholder, axis=1)

# Forward passes
cell = tf.nn.rnn_cell.BasicLSTMCell(state_size, state_is_tuple=True)
states_series, current_state = tf.nn.rnn(cell, inputs_series, init_state)

logits_series = [tf.matmul(state, W2) + b2 for state in states_series] #Broadcasted addition
predictions_series = [tf.nn.softmax(logits) for logits in logits_series]

losses = [tf.nn.sparse_softmax_cross_entropy_with_logits(logits, labels) for logits, labels in zip(logits_series,labels_series)]
total_loss = tf.reduce_mean(losses)

train_step = tf.train.AdagradOptimizer(0.3).minimize(total_loss)

def plot(loss_list, predictions_series, batchX, batchY):
    plt.subplot(2, 3, 1)
    plt.cla()
    plt.plot(loss_list)

    for batch_series_idx in range(5):
        one_hot_output_series = np.array(predictions_series)[:, batch_series_idx, :]
        single_output_series = np.array([(1 if out[0] < 0.5 else 0) for out in one_hot_output_series])

        plt.subplot(2, 3, batch_series_idx + 2)
        plt.cla()
        plt.axis([0, truncated_backprop_length, 0, 2])
        left_offset = range(truncated_backprop_length)
        plt.bar(left_offset, batchX[batch_series_idx, :], width=1, color="blue")
        plt.bar(left_offset, batchY[batch_series_idx, :] * 0.5, width=1, color="red")
        plt.bar(left_offset, single_output_series * 0.3, width=1, color="green")

    plt.draw()
    plt.pause(0.0001)


with tf.Session() as sess:
    sess.run(tf.initialize_all_variables())
    plt.ion()
    plt.figure()
    plt.show()
    loss_list = []

    for epoch_idx in range(num_epochs):
        x,y = generateData()
        _current_cell_state = np.zeros((batch_size, state_size))
        _current_hidden_state = np.zeros((batch_size, state_size))

        print("New data, epoch", epoch_idx)

        for batch_idx in range(num_batches):
            start_idx = batch_idx * truncated_backprop_length
            end_idx = start_idx + truncated_backprop_length

            batchX = x[:,start_idx:end_idx]
            batchY = y[:,start_idx:end_idx]

            _total_loss, _train_step, _current_state, _predictions_series = sess.run(
                [total_loss, train_step, current_state, predictions_series],
                feed_dict={
                    batchX_placeholder: batchX,
                    batchY_placeholder: batchY,
                    cell_state: _current_cell_state,
                    hidden_state: _current_hidden_state

                })

           # _current_cell_state, _current_hidden_state = _current_state

            loss_list.append(_total_loss)

            if batch_idx%100 == 0:
                print("Step",batch_idx, "Batch loss", _total_loss)
                plot(loss_list, _predictions_series, batchX, batchY)

plt.ioff()
plt.show()
# Out:
# WARNING:tensorflow:From <ipython-input-1-2a843370fe28>:73 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# WARNING:tensorflow:From <ipython-input-1-2a843370fe28>:73 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# New data, epoch 0
# Step 0 Batch loss 0.693885
# /home/wxk/anaconda2/lib/python2.7/site-packages/matplotlib/backend_bases.py:2437: MatplotlibDeprecationWarning: Using default event loop until function specific to this GUI is implemented
#   warnings.warn(str, mplDeprecation)
# Step 100 Batch loss 0.566654
# Step 200 Batch loss 0.588554
# Step 300 Batch loss 0.413657
# Step 400 Batch loss 0.535548
# Step 500 Batch loss 0.250319
# Step 600 Batch loss 0.210034
# New data, epoch 1
# Step 0 Batch loss 0.184735
# Step 100 Batch loss 0.156212
# Step 200 Batch loss 0.168181
# Step 300 Batch loss 0.15525
# Step 400 Batch loss 0.137878
# Step 500 Batch loss 0.158282
# Step 600 Batch loss 0.148039
# New data, epoch 2
# Step 0 Batch loss 0.15512
# Step 100 Batch loss 0.15984
# Step 200 Batch loss 0.146108
# Step 300 Batch loss 0.142652
# Step 400 Batch loss 0.159175
# Step 500 Batch loss 0.13504
# Step 600 Batch loss 0.146143
# New data, epoch 3
# Step 0 Batch loss 0.141673
# Step 100 Batch loss 0.172899
# Step 200 Batch loss 0.142102
# Step 300 Batch loss 0.156121
# Step 400 Batch loss 0.143682
# Step 500 Batch loss 0.145654
# Step 600 Batch loss 0.144739
# New data, epoch 4
# Step 0 Batch loss 0.137669
# Step 100 Batch loss 0.146638
# Step 200 Batch loss 0.149654
# Step 300 Batch loss 0.148665
# Step 400 Batch loss 0.134485
# Step 500 Batch loss 0.159563
# Step 600 Batch loss 0.158073
# New data, epoch 5
# Step 0 Batch loss 0.141402
# Step 100 Batch loss 0.155828
# Step 200 Batch loss 0.161259
# Step 300 Batch loss 0.140951
# Step 400 Batch loss 0.135693
# Step 500 Batch loss 0.138984
# Step 600 Batch loss 0.144621
# New data, epoch 6
# Step 0 Batch loss 0.147555
# Step 100 Batch loss 0.139274
# Step 200 Batch loss 0.130869
# Step 300 Batch loss 0.145617
# Step 400 Batch loss 0.148354
# Step 500 Batch loss 0.129569
# Step 600 Batch loss 0.158165
# New data, epoch 7
# Step 0 Batch loss 0.155143
# Step 100 Batch loss 0.138825
# Step 200 Batch loss 0.140932
# Step 300 Batch loss 0.134731
# Step 400 Batch loss 0.150535
# Step 500 Batch loss 0.144791
# Step 600 Batch loss 0.14938
# New data, epoch 8
# Step 0 Batch loss 0.137554
# Step 100 Batch loss 0.135341
# Step 200 Batch loss 0.140079
# Step 300 Batch loss 0.153001
# Step 400 Batch loss 0.141949
# Step 500 Batch loss 0.138826
# Step 600 Batch loss 0.133543
# New data, epoch 9
# Step 0 Batch loss 0.147133
# Step 100 Batch loss 0.149622
# Step 200 Batch loss 0.146337
# Step 300 Batch loss 0.138527
# Step 400 Batch loss 0.145212
# Step 500 Batch loss 0.132739
# Step 600 Batch loss 0.156316
# New data, epoch 10
# Step 0 Batch loss 0.151727
# Step 100 Batch loss 0.131158
# Step 200 Batch loss 0.136666
# Step 300 Batch loss 0.136807
# Step 400 Batch loss 0.136175
# Step 500 Batch loss 0.166563
# Step 600 Batch loss 0.133302
# New data, epoch 11
# Step 0 Batch loss 0.134508
# Step 100 Batch loss 0.144848
# Step 200 Batch loss 0.137809
# Step 300 Batch loss 0.138801
# Step 400 Batch loss 0.167132
# Step 500 Batch loss 0.142135
# Step 600 Batch loss 0.151305
# New data, epoch 12
# Step 0 Batch loss 0.137501
# Step 100 Batch loss 0.136292
# Step 200 Batch loss 0.139665
# Step 300 Batch loss 0.141829
# Step 400 Batch loss 0.12626
# Step 500 Batch loss 0.141236
# Step 600 Batch loss 0.132824
# New data, epoch 13
# Step 0 Batch loss 0.154288
# Step 100 Batch loss 0.133227
# Step 200 Batch loss 0.144406
# Step 300 Batch loss 0.141914
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-2a843370fe28> in <module>()
#     107             if batch_idx%100 == 0:
#     108                 print("Step",batch_idx, "Batch loss", _total_loss)
# --> 109                 plot(loss_list, _predictions_series, batchX, batchY)
#     110
#     111 plt.ioff()
#
# <ipython-input-1-2a843370fe28> in plot(loss_list, predictions_series, batchX, batchY)
#      63         left_offset = range(truncated_backprop_length)
#      64         plt.bar(left_offset, batchX[batch_series_idx, :], width=1, color="blue")
# ---> 65         plt.bar(left_offset, batchY[batch_series_idx, :] * 0.5, width=1, color="red")
#      66         plt.bar(left_offset, single_output_series * 0.3, width=1, color="green")
#      67
#
# /home/wxk/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in bar(left, height, width, bottom, hold, data, **kwargs)
#    2641     try:
#    2642         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2643                      **kwargs)
#    2644     finally:
#    2645         ax.hold(washold)
#
# /home/wxk/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /home/wxk/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in bar(self, left, height, width, bottom, **kwargs)
#    2132             r.get_path()._interpolation_steps = 100
#    2133             #print r.get_label(), label, 'label' in kwargs
# -> 2134             self.add_patch(r)
#    2135             patches.append(r)
#    2136
#
# /home/wxk/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in add_patch(self, p)
#    1781         if p.get_clip_path() is None:
#    1782             p.set_clip_path(self.patch)
# -> 1783         self._update_patch_limits(p)
#    1784         self.patches.append(p)
#    1785         p._remove_method = lambda h: self.patches.remove(h)
#
# /home/wxk/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _update_patch_limits(self, patch)
#    1801         vertices = patch.get_path().vertices
#    1802         if vertices.size > 0:
# -> 1803             xys = patch.get_patch_transform().transform(vertices)
#    1804             if patch.get_data_transform() != self.transData:
#    1805                 patch_to_data = (patch.get_data_transform() -
#
# /home/wxk/anaconda2/lib/python2.7/site-packages/matplotlib/patches.pyc in get_patch_transform(self)
#     670
#     671     def get_patch_transform(self):
# --> 672         self._update_patch_transform()
#     673         return self._rect_transform
#     674
#
# /home/wxk/anaconda2/lib/python2.7/site-packages/matplotlib/patches.pyc in _update_patch_transform(self)
#     665         bbox = transforms.Bbox.from_bounds(x, y, width, height)
#     666         rot_trans = transforms.Affine2D()
# --> 667         rot_trans.rotate_deg_around(x, y, self._angle)
#     668         self._rect_transform = transforms.BboxTransformTo(bbox)
#     669         self._rect_transform += rot_trans
#
# /home/wxk/anaconda2/lib/python2.7/site-packages/matplotlib/transforms.pyc in rotate_deg_around(self, x, y, degrees)
#    1931         and :meth:`scale`.
#    1932         """
# -> 1933         return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
#    1934
#    1935     def translate(self, tx, ty):
#
# /home/wxk/anaconda2/lib/python2.7/site-packages/matplotlib/transforms.pyc in translate(self, tx, ty)
#    1945             np.float_)
#    1946         self._mtx = np.dot(translate_mtx, self._mtx)
# -> 1947         self.invalidate()
#    1948         return self
#    1949
#
# /home/wxk/anaconda2/lib/python2.7/site-packages/matplotlib/transforms.pyc in invalidate(self)
#     134         if self.is_affine:
#     135             value = self.INVALID_AFFINE
# --> 136         return self._invalidate_internal(value, invalidating_node=self)
#     137
#     138     def _invalidate_internal(self, value, invalidating_node):
#
# /home/wxk/anaconda2/lib/python2.7/site-packages/matplotlib/transforms.pyc in _invalidate_internal(self, value, invalidating_node)
#     156             self._invalid = value
#     157
# --> 158             for parent in list(six.itervalues(self._parents)):
#     159                 parent._invalidate_internal(value=value,
#     160                                             invalidating_node=self)
#
# KeyboardInterrupt:
