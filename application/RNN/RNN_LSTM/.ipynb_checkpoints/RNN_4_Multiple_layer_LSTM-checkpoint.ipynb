# %%
#source: https://medium.com/@erikhallstrm/using-the-tensorflow-multilayered-lstm-api-f6e7da7bbe40

# %%
from __future__ import print_function, division
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

num_epochs = 100
total_series_length = 50000
truncated_backprop_length = 15
state_size = 4
num_classes = 2
echo_step = 3
batch_size = 5
num_batches = total_series_length//batch_size//truncated_backprop_length
num_layers = 3

def generateData():
    x = np.array(np.random.choice(2, total_series_length, p=[0.5, 0.5]))
    y = np.roll(x, echo_step)
    y[0:echo_step] = 0

    x = x.reshape((batch_size, -1))  # The first index changing slowest, subseries as rows
    y = y.reshape((batch_size, -1))

    return (x, y)

batchX_placeholder = tf.placeholder(tf.float32, [batch_size, truncated_backprop_length])
batchY_placeholder = tf.placeholder(tf.int32, [batch_size, truncated_backprop_length])

init_state = tf.placeholder(tf.float32, [num_layers, 2, batch_size, state_size])

state_per_layer_list = tf.unpack(init_state, axis=0)
rnn_tuple_state = tuple(
    [tf.nn.rnn_cell.LSTMStateTuple(state_per_layer_list[idx][0], state_per_layer_list[idx][1])
     for idx in range(num_layers)]
)

W2 = tf.Variable(np.random.rand(state_size, num_classes),dtype=tf.float32)
b2 = tf.Variable(np.zeros((1,num_classes)), dtype=tf.float32)

# Unpack columns
inputs_series = tf.split(1, truncated_backprop_length, batchX_placeholder)
labels_series = tf.unpack(batchY_placeholder, axis=1)

# Forward passes
cell = tf.nn.rnn_cell.LSTMCell(state_size, state_is_tuple=True)
cell = tf.nn.rnn_cell.MultiRNNCell([cell] * num_layers, state_is_tuple=True)
states_series, current_state = tf.nn.rnn(cell, inputs_series, initial_state=rnn_tuple_state)

logits_series = [tf.matmul(state, W2) + b2 for state in states_series] #Broadcasted addition
predictions_series = [tf.nn.softmax(logits) for logits in logits_series]

losses = [tf.nn.sparse_softmax_cross_entropy_with_logits(logits, labels) for logits, labels in zip(logits_series,labels_series)]
total_loss = tf.reduce_mean(losses)

train_step = tf.train.AdagradOptimizer(0.3).minimize(total_loss)

def plot(loss_list, predictions_series, batchX, batchY):
    plt.subplot(2, 3, 1)
    plt.cla()
    plt.plot(loss_list)

    for batch_series_idx in range(5):
        one_hot_output_series = np.array(predictions_series)[:, batch_series_idx, :]
        single_output_series = np.array([(1 if out[0] < 0.5 else 0) for out in one_hot_output_series])

        plt.subplot(2, 3, batch_series_idx + 2)
        plt.cla()
        plt.axis([0, truncated_backprop_length, 0, 2])
        left_offset = range(truncated_backprop_length)
        plt.bar(left_offset, batchX[batch_series_idx, :], width=1, color="blue")
        plt.bar(left_offset, batchY[batch_series_idx, :] * 0.5, width=1, color="red")
        plt.bar(left_offset, single_output_series * 0.3, width=1, color="green")

    plt.draw()
    plt.pause(0.0001)


with tf.Session() as sess:
    sess.run(tf.initialize_all_variables())
    plt.ion()
    plt.figure()
    plt.show()
    loss_list = []

    for epoch_idx in range(num_epochs):
        x,y = generateData()

        _current_state = np.zeros((num_layers, 2, batch_size, state_size))

        print("New data, epoch", epoch_idx)

        for batch_idx in range(num_batches):
            start_idx = batch_idx * truncated_backprop_length
            end_idx = start_idx + truncated_backprop_length

            batchX = x[:,start_idx:end_idx]
            batchY = y[:,start_idx:end_idx]

            _total_loss, _train_step, _current_state, _predictions_series = sess.run(
                [total_loss, train_step, current_state, predictions_series],
                feed_dict={
                    batchX_placeholder: batchX,
                    batchY_placeholder: batchY,
                    init_state: _current_state
                })


            loss_list.append(_total_loss)

            if batch_idx%100 == 0:
                print("Step",batch_idx, "Batch loss", _total_loss)
                plot(loss_list, _predictions_series, batchX, batchY)

plt.ioff()
plt.show()
# Out:
# WARNING:tensorflow:From <ipython-input-1-8c718c1c1eac>:79 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# New data, epoch 0
# Step 0 Batch loss 0.69076
# /home/wxk/anaconda2/lib/python2.7/site-packages/matplotlib/backend_bases.py:2437: MatplotlibDeprecationWarning: Using default event loop until function specific to this GUI is implemented
#   warnings.warn(str, mplDeprecation)
# Step 100 Batch loss 0.547723
# Step 200 Batch loss 0.541705
# Step 300 Batch loss 0.492514
# Step 400 Batch loss 0.192074
# Step 500 Batch loss 0.0103808
# Step 600 Batch loss 0.00397018
# New data, epoch 1
# Step 0 Batch loss 0.533897
# Step 100 Batch loss 0.0019578
# Step 200 Batch loss 0.00139831
# Step 300 Batch loss 0.000966411
# Step 400 Batch loss 0.000873653
# Step 500 Batch loss 0.000719549
# Step 600 Batch loss 0.000777945
# New data, epoch 2
# Step 0 Batch loss 0.703527
# Step 100 Batch loss 0.000653617
# Step 200 Batch loss 0.000531836
# Step 300 Batch loss 0.000559147
# Step 400 Batch loss 0.000390053
# Step 500 Batch loss 0.000397191
# Step 600 Batch loss 0.000375399
# New data, epoch 3
# Step 0 Batch loss 0.370948
# Step 100 Batch loss 0.000397584
# Step 200 Batch loss 0.000378187
# Step 300 Batch loss 0.000279044
# Step 400 Batch loss 0.00033502
# Step 500 Batch loss 0.000289758
# Step 600 Batch loss 0.000280394
# New data, epoch 4
# Step 0 Batch loss 0.190823
# Step 100 Batch loss 0.00291287
# Step 200 Batch loss 0.00139745
# Step 300 Batch loss 0.00107787
# Step 400 Batch loss 0.000856527
# Step 500 Batch loss 0.000702618
# Step 600 Batch loss 0.00048525
# New data, epoch 5
# Step 0 Batch loss 0.208943
# Step 100 Batch loss 0.00043885
# Step 200 Batch loss 0.000547274
# Step 300 Batch loss 0.000377617
# Step 400 Batch loss 0.00041223
# Step 500 Batch loss 0.000309042
# Step 600 Batch loss 0.00026785
# New data, epoch 6
# Step 0 Batch loss 0.324019
# Step 100 Batch loss 0.00035993
# Step 200 Batch loss 0.000377115
# Step 300 Batch loss 0.000312745
# Step 400 Batch loss 0.000244769
# Step 500 Batch loss 0.000241585
# Step 600 Batch loss 0.00027766
# New data, epoch 7
# Step 0 Batch loss 0.337356
# Step 100 Batch loss 0.00025853
# Step 200 Batch loss 0.000211891
# Step 300 Batch loss 0.000197724
# Step 400 Batch loss 0.000195087
# Step 500 Batch loss 0.000167939
# Step 600 Batch loss 0.000168854
# New data, epoch 8
# Step 0 Batch loss 0.775285
# Step 100 Batch loss 0.000257858
# Step 200 Batch loss 0.000198856
# Step 300 Batch loss 0.000191879
# Step 400 Batch loss 0.000192568
# Step 500 Batch loss 0.000191773
# Step 600 Batch loss 0.000182381
# New data, epoch 9
# Step 0 Batch loss 0.207932
# Step 100 Batch loss 0.000205746
# Step 200 Batch loss 0.000160238
# Step 300 Batch loss 0.000156774
# Step 400 Batch loss 0.000133576
# Step 500 Batch loss 0.000174263
# Step 600 Batch loss 0.000131113
# New data, epoch 10
# Step 0 Batch loss 0.38142
# Step 100 Batch loss 0.000197329
# Step 200 Batch loss 0.000152851
# Step 300 Batch loss 0.000144
# Step 400 Batch loss 0.000157497
# Step 500 Batch loss 0.000150809
# Step 600 Batch loss 0.000102157
# New data, epoch 11
# Step 0 Batch loss 0.337464
# Step 100 Batch loss 0.000154751
# Step 200 Batch loss 0.000110992
# Step 300 Batch loss 0.000141031
# Step 400 Batch loss 0.000110786
# Step 500 Batch loss 0.000119792
# Step 600 Batch loss 0.000122023
# New data, epoch 12
# Step 0 Batch loss 0.265934
# Step 100 Batch loss 0.000124592
# Step 200 Batch loss 0.000112819
# Step 300 Batch loss 0.00010621
# Step 400 Batch loss 8.47317e-05
# Step 500 Batch loss 9.67499e-05
# Step 600 Batch loss 8.35151e-05
# New data, epoch 13
# Step 0 Batch loss 0.258929
# Step 100 Batch loss 0.000148828
# Step 200 Batch loss 0.000118396
# Step 300 Batch loss 0.000130701
# Step 400 Batch loss 0.00012183
# Step 500 Batch loss 9.32113e-05
# Step 600 Batch loss 8.51941e-05
# New data, epoch 14
# Step 0 Batch loss 0.372072
# Step 100 Batch loss 0.000166272
# Step 200 Batch loss 0.000173209
# Step 300 Batch loss 0.000122889
# Step 400 Batch loss 0.000100458
# Step 500 Batch loss 9.96687e-05
# Step 600 Batch loss 9.80078e-05
# New data, epoch 15
# Step 0 Batch loss 0.348739
# Step 100 Batch loss 9.49238e-05
# Step 200 Batch loss 9.04262e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8c718c1c1eac> in <module>()
#     102                     batchX_placeholder: batchX,
#     103                     batchY_placeholder: batchY,
# --> 104                     init_state: _current_state
#     105                 })
#     106
#
# /home/wxk/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/wxk/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /home/wxk/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/wxk/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /home/wxk/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
